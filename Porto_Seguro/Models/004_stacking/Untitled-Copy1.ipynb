# %%
import pandas as pd

# %%
import os
import pandas as pd

# %%
train = pd.DataFrame()
test = pd.DataFrame()

# %%
foldernames = os.popen('ls data').readlines()

# %%
for foldername in foldernames:
    foldername = foldername[:-1]
    train[foldername] = pd.read_csv('data/{0}/train4stack.csv'.format(foldername),nrows=5000)
    #test[foldername] = pd.read_csv('data/{0}/test4stack.csv'.format(foldername),nrows=100)

# %%
train
# Out:
#     changlin_20171108_1  changlin_20171108_2  guoli_20171108
# 0              0.044521             0.046646        0.994861
# 1              0.035425             0.033705        1.047057
# 2              0.017495             0.021387        1.272133
# 3              0.033988             0.014646        0.477906
# 4              0.031818             0.031650        0.769130
# 5              0.022622             0.028122        0.345787
# 6              0.026653             0.017518        0.462142
# 7              0.030753             0.025165        0.970815
# 8              0.035954             0.026805        0.860347
# 9              0.040028             0.048466        0.465406
# 10             0.034284             0.030249        1.020245
# 11             0.031727             0.028520        1.110934
# 12             0.034298             0.021898        1.021332
# 13             0.049591             0.037655        0.309794
# ...
